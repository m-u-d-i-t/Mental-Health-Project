# %%
# !pip install kaggle
# !pip install ray==2.10.0
# !pip install autogluon.tabular
# !pip install -U ipywidgets
# !pip install catboost
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.1/65.1 MB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 352.2/352.2 kB 27.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.2/266.2 kB 23.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.1/64.1 kB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.2/68.2 kB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.2/139.2 kB 12.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 101.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.2/83.2 kB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 11.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 84.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 67.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 3.6.10
# ...

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-75c1e9e9-4829-4549-810c-0c7f146b48e1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-75c1e9e9-4829-4549-810c-0c7f146b48e1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p ~/.kaggle
# !mv kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle competitions download -c playground-series-s4e11
# Out:
# ...
#  88% 4.00M/4.55M [00:01<00:00, 4.37MB/s]
# 100% 4.55M/4.55M [00:01<00:00, 3.55MB/s]

# %%
# !unzip playground-series-s4e11.zip
# Out:
# Archive:  playground-series-s4e11.zip
#   inflating: sample_submission.csv
#   inflating: test.csv
#   inflating: train.csv

# %%
import pandas as pd
import numpy as np

# %%
df_train=pd.read_csv('/content/train.csv')
df_test=pd.read_csv('/content/test.csv')

# %%
merged_df = pd.concat([df_train, df_test], ignore_index=True)
merged_df
# Out:
#             id      Name  Gender   Age           City  \
# 0            0  Aaradhya  Female  49.0       Ludhiana
# 1            1     Vivan    Male  26.0       Varanasi
# 2            2    Yuvraj    Male  33.0  Visakhapatnam
# 3            3    Yuvraj    Male  22.0         Mumbai
# 4            4      Rhea  Female  30.0         Kanpur
# ...        ...       ...     ...   ...            ...
# 234495  234495      Zoya  Female  49.0         Jaipur
# 234496  234496     Shlok    Male  29.0      Ahmedabad
# 234497  234497     Rishi    Male  24.0  Visakhapatnam
# 234498  234498    Eshita  Female  23.0         Kalyan
# 234499  234499     Gauri  Female  43.0       Varanasi
#
#        Working Professional or Student              Profession  \
# 0                 Working Professional                    Chef
# 1                 Working Professional                 Teacher
# 2                              Student                     NaN
# ...

# %%
merged_df.isnull().sum()
# Out:
# id                                            0
# Name                                          0
# Gender                                        0
# Age                                           0
# City                                          0
# Working Professional or Student               0
# Profession                                61262
# Academic Pressure                        187836
# Work Pressure                             46696
# CGPA                                     187836
# Study Satisfaction                       187836
# Job Satisfaction                          46684
# Sleep Duration                                0
# Dietary Habits                                9
# Degree                                        4
# Have you ever had suicidal thoughts ?         0
# Work/Study Hours                              0
# Financial Stress                              4
# Family History of Mental Illness              0
# Depression                                93800
# ...

# %%
merged_df.drop(['Name'],axis=1,inplace=True)
merged_df.head()
# Out:
#    id  Gender   Age           City Working Professional or Student  \
# 0   0  Female  49.0       Ludhiana            Working Professional
# 1   1    Male  26.0       Varanasi            Working Professional
# 2   2    Male  33.0  Visakhapatnam                         Student
# 3   3    Male  22.0         Mumbai            Working Professional
# 4   4  Female  30.0         Kanpur            Working Professional
#
#          Profession  Academic Pressure  Work Pressure  CGPA  \
# 0              Chef                NaN            5.0   NaN
# 1           Teacher                NaN            4.0   NaN
# 2               NaN                5.0            NaN  8.97
# 3           Teacher                NaN            5.0   NaN
# 4  Business Analyst                NaN            1.0   NaN
#
#    Study Satisfaction  Job Satisfaction     Sleep Duration Dietary Habits  \
# 0                 NaN               2.0  More than 8 hours        Healthy
# ...

# %%
merged_df['Gender']=merged_df['Gender'].map({'Male':0,'Female':1})

# %%
merged_df.head()
# Out:
#    id  Gender   Age           City Working Professional or Student  \
# 0   0       1  49.0       Ludhiana            Working Professional
# 1   1       0  26.0       Varanasi            Working Professional
# 2   2       0  33.0  Visakhapatnam                         Student
# 3   3       0  22.0         Mumbai            Working Professional
# 4   4       1  30.0         Kanpur            Working Professional
#
#          Profession  Academic Pressure  Work Pressure  CGPA  \
# 0              Chef                NaN            5.0   NaN
# 1           Teacher                NaN            4.0   NaN
# 2               NaN                5.0            NaN  8.97
# 3           Teacher                NaN            5.0   NaN
# 4  Business Analyst                NaN            1.0   NaN
#
#    Study Satisfaction  Job Satisfaction     Sleep Duration Dietary Habits  \
# 0                 NaN               2.0  More than 8 hours        Healthy
# ...

# %%
merged_df['Working Professional or Student']=merged_df['Working Professional or Student'].map({'Working Professional':0,'Student':1})
merged_df.head()
# Out:
#    id  Gender   Age           City  Working Professional or Student  \
# 0   0       1  49.0       Ludhiana                                0
# 1   1       0  26.0       Varanasi                                0
# 2   2       0  33.0  Visakhapatnam                                1
# 3   3       0  22.0         Mumbai                                0
# 4   4       1  30.0         Kanpur                                0
#
#          Profession  Academic Pressure  Work Pressure  CGPA  \
# 0              Chef                NaN            5.0   NaN
# 1           Teacher                NaN            4.0   NaN
# 2               NaN                5.0            NaN  8.97
# 3           Teacher                NaN            5.0   NaN
# 4  Business Analyst                NaN            1.0   NaN
#
#    Study Satisfaction  Job Satisfaction     Sleep Duration Dietary Habits  \
# 0                 NaN               2.0  More than 8 hours        Healthy
# ...

# %%
merged_df['Academic Pressure'].fillna(merged_df['Academic Pressure'].median(),inplace=True)
merged_df['Academic Pressure'].isnull().sum()
# Out:
# <ipython-input-15-0a673c62913c>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   merged_df['Academic Pressure'].fillna(merged_df['Academic Pressure'].median(),inplace=True)
# 0

# %%
merged_df.head()
# Out:
#    id  Gender   Age           City  Working Professional or Student  \
# 0   0       1  49.0       Ludhiana                                0
# 1   1       0  26.0       Varanasi                                0
# 2   2       0  33.0  Visakhapatnam                                1
# 3   3       0  22.0         Mumbai                                0
# 4   4       1  30.0         Kanpur                                0
#
#          Profession  Academic Pressure  Work Pressure  CGPA  \
# 0              Chef                3.0            5.0   NaN
# 1           Teacher                3.0            4.0   NaN
# 2               NaN                5.0            NaN  8.97
# 3           Teacher                3.0            5.0   NaN
# 4  Business Analyst                3.0            1.0   NaN
#
#    Study Satisfaction  Job Satisfaction     Sleep Duration Dietary Habits  \
# 0                 NaN               2.0  More than 8 hours        Healthy
# ...

# %%
merged_df['Work Pressure'].fillna(merged_df['Work Pressure'].median(),inplace=True)
merged_df['CGPA'].fillna(merged_df['CGPA'].median(),inplace=True)
merged_df['Study Satisfaction'].fillna(merged_df['Study Satisfaction'].median(),inplace=True)
merged_df['Job Satisfaction'].fillna(merged_df['Job Satisfaction'].median(),inplace=True)
merged_df.head()
# Out:
# <ipython-input-17-3bdfac11bb0e>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   merged_df['Work Pressure'].fillna(merged_df['Work Pressure'].median(),inplace=True)
# <ipython-input-17-3bdfac11bb0e>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
merged_df.isnull().sum()
# Out:
# id                                           0
# Gender                                       0
# Age                                          0
# City                                         0
# Working Professional or Student              0
# Profession                               61262
# Academic Pressure                            0
# Work Pressure                                0
# CGPA                                         0
# Study Satisfaction                           0
# Job Satisfaction                             0
# Sleep Duration                               0
# Dietary Habits                               9
# Degree                                       4
# Have you ever had suicidal thoughts ?        0
# Work/Study Hours                             0
# Financial Stress                             4
# Family History of Mental Illness             0
# Depression                               93800
# dtype: int64

# %%
merged_df['Dietary Habits'].mode()[0]
# Out:
# 'Moderate'

# %%
merged_df['Dietary Habits'].fillna(merged_df['Dietary Habits'].mode()[0],inplace=True)
merged_df['Degree'].fillna(merged_df['Degree'].mode()[0],inplace=True)
merged_df['Financial Stress'].fillna(merged_df['Financial Stress'].mode()[0],inplace=True)
# Out:
# <ipython-input-20-72ae7807985a>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   merged_df['Dietary Habits'].fillna(merged_df['Dietary Habits'].mode()[0],inplace=True)
# <ipython-input-20-72ae7807985a>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
merged_df.isnull().sum()
# Out:
# id                                           0
# Gender                                       0
# Age                                          0
# City                                         0
# Working Professional or Student              0
# Profession                               61262
# Academic Pressure                            0
# Work Pressure                                0
# CGPA                                         0
# Study Satisfaction                           0
# Job Satisfaction                             0
# Sleep Duration                               0
# Dietary Habits                               0
# Degree                                       0
# Have you ever had suicidal thoughts ?        0
# Work/Study Hours                             0
# Financial Stress                             0
# Family History of Mental Illness             0
# Depression                               93800
# dtype: int64

# %%
# prof_mode = merged_df['Profession'].mode()[0]


# prof_to_replace = merged_df['Profession'].value_counts()[merged_df['Profession'].value_counts() <= 15].index


# merged_df['Profession'] = merged_df['Profession'].apply(lambda x: prof_mode if x in prof_to_replace else x)

# %%
degree_mode = merged_df['Degree'].mode()[0]

degree_to_replace = merged_df['Degree'].value_counts()[merged_df['Degree'].value_counts() <= 14].index

merged_df['Degree'] = merged_df['Degree'].apply(lambda x: degree_mode if x in degree_to_replace else x)

# %%
merged_df['Degree'].value_counts()
# Out:
# Degree
# Class 12    24743
# B.Ed        19453
# B.Arch      14779
# B.Com       13552
# B.Pharm      9843
# BCA          9608
# M.Ed         9375
# MCA          8672
# BBA          8417
# BSc          8341
# MSc          7975
# LLM          7780
# M.Pharm      7532
# M.Tech       7492
# B.Tech       7310
# LLB          7286
# BHM          7081
# MBA          6288
# BA           6240
# ME           6023
# MD           5672
# MHM          5435
# BE           5270
# M.Com        5222
# PhD          5176
# MBBS         5115
# MA           4820
# Name: count, dtype: int64

# %%
# prof_df=merged_df[~merged_df['Profession'].isnull() & ~merged_df['Degree'].isnull()]
# profession_array=prof_df['Profession'].unique()
# prof_max_dict={}
# for i in profession_array:
#   prof_max_dict[i]=prof_df[prof_df['Profession']==i]['Degree'].mode()[0]

# %%
# prof_max_dict

# %%
# degree_to_profession = {v: k for k, v in prof_max_dict.items()}

# merged_df['Profession'] = merged_df.apply(
#     lambda row: degree_to_profession.get(row['Degree'], row['Profession']) if pd.isna(row['Profession']) else row['Profession'],
#     axis=1
# )

# %%
# Calculating the mode of the 'City' column
city_mode = merged_df['City'].mode()[0]

# Identifying cities with a frequency of 7 or less
cities_to_replace = merged_df['City'].value_counts()[merged_df['City'].value_counts() <= 7].index

# Replacing those cities with the mode
merged_df['City'] = merged_df['City'].apply(lambda x: city_mode if x in cities_to_replace else x)

# %%
merged_df
# Out:
#             id  Gender   Age           City  Working Professional or Student  \
# 0            0       1  49.0       Ludhiana                                0
# 1            1       0  26.0       Varanasi                                0
# 2            2       0  33.0  Visakhapatnam                                1
# 3            3       0  22.0         Mumbai                                0
# 4            4       1  30.0         Kanpur                                0
# ...        ...     ...   ...            ...                              ...
# 234495  234495       1  49.0         Jaipur                                0
# 234496  234496       0  29.0      Ahmedabad                                0
# 234497  234497       0  24.0  Visakhapatnam                                1
# 234498  234498       1  23.0         Kalyan                                0
# 234499  234499       1  43.0       Varanasi                                0
#
# ...

# %%
merged_df['Sleep Duration'].value_counts()
# Out:
# Sleep Duration
# Less than 5 hours                      64445
# 7-8 hours                              61460
# More than 8 hours                      54916
# 5-6 hours                              53546
# 6-7 hours                                 15
# 3-4 hours                                 15
# 4-5 hours                                 13
# 2-3 hours                                  9
# 8-9 hours                                  8
# 4-6 hours                                  7
# 1-6 hours                                  6
# No                                         4
# 6-8 hours                                  4
# 1-2 hours                                  3
# Unhealthy                                  3
# 9-5                                        3
# 9-5 hours                                  3
# 9-11 hours                                 3
# than 5 hours                               2
# 10-11 hours                                2
# ...

# %%
sleep_mode = merged_df['Sleep Duration'].mode()[0]

sleep_to_replace = merged_df['Sleep Duration'].value_counts()[merged_df['Sleep Duration'].value_counts() <= 15].index

merged_df['Sleep Duration'] = merged_df['Sleep Duration'].apply(lambda x: sleep_mode if x in sleep_to_replace else x)

# %%
dietary_mode = merged_df['Dietary Habits'].mode()[0]

diet_to_replace = merged_df['Dietary Habits'].value_counts()[merged_df['Dietary Habits'].value_counts() <= 8].index

merged_df['Dietary Habits'] = merged_df['Dietary Habits'].apply(lambda x: dietary_mode if x in diet_to_replace else x)

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234500 entries, 0 to 234499
# Data columns (total 19 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   id                                     234500 non-null  int64
#  1   Gender                                 234500 non-null  int64
#  2   Age                                    234500 non-null  float64
#  3   City                                   234500 non-null  object
#  4   Working Professional or Student        234500 non-null  int64
#  5   Profession                             173238 non-null  object
#  6   Academic Pressure                      234500 non-null  float64
#  7   Work Pressure                          234500 non-null  float64
#  8   CGPA                                   234500 non-null  float64
#  9   Study Satisfaction                     234500 non-null  float64
# ...

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234500 entries, 0 to 234499
# Data columns (total 19 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   id                                     234500 non-null  int64
#  1   Gender                                 234500 non-null  int64
#  2   Age                                    234500 non-null  float64
#  3   City                                   234500 non-null  object
#  4   Working Professional or Student        234500 non-null  int64
#  5   Profession                             173238 non-null  object
#  6   Academic Pressure                      234500 non-null  float64
#  7   Work Pressure                          234500 non-null  float64
#  8   CGPA                                   234500 non-null  float64
#  9   Study Satisfaction                     234500 non-null  float64
# ...

# %%
merged_df['Have you ever had suicidal thoughts ?'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
merged_df['Have you ever had suicidal thoughts ?']=merged_df['Have you ever had suicidal thoughts ?'].map({'Yes':1,'No':0})

# %%
merged_df['Family History of Mental Illness'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
merged_df['Family History of Mental Illness']=merged_df['Family History of Mental Illness'].map({'Yes':1,'No':0})

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234500 entries, 0 to 234499
# Data columns (total 19 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   id                                     234500 non-null  int64
#  1   Gender                                 234500 non-null  int64
#  2   Age                                    234500 non-null  float64
#  3   City                                   234500 non-null  object
#  4   Working Professional or Student        234500 non-null  int64
#  5   Profession                             173238 non-null  object
#  6   Academic Pressure                      234500 non-null  float64
#  7   Work Pressure                          234500 non-null  float64
#  8   CGPA                                   234500 non-null  float64
#  9   Study Satisfaction                     234500 non-null  float64
# ...

# %%
#merged_id=merged_df['id']

# %%
#merged_df.drop('id',axis=1,inplace=True)

# %%
# merged_train_df=merged_df[:140700]

# merged_test_df=merged_df[140700:]

# %%
#y_preds

# %%
# numeric_df = merged_df.select_dtypes(include=['number'])

# numeric_df.corr()

# professional_merged=merged_df[(merged_df['Degree'] == 'Class 12') & (~merged_df['Profession'].isnull())][['Gender','Age','Work/Study Hours','Sleep Duration','Dietary Habits','Working Professional or Student','Degree', 'CGPA','Study Satisfaction','Academic Pressure','Profession', 'Financial Stress']]

# %%
# professional_merged = pd.get_dummies(professional_merged, columns=['Sleep Duration','Dietary Habits','Degree'], dtype=int)

# %%
# professional_merged_test=merged_df[(merged_df['Degree'] == 'Class 12') & (merged_df['Profession'].isnull())][['Gender','Age','Work/Study Hours','Sleep Duration','Dietary Habits','Working Professional or Student','Degree', 'CGPA','Study Satisfaction','Academic Pressure','Profession', 'Financial Stress']]
# X_prof_test=pd.get_dummies(professional_merged_test, columns=['Sleep Duration','Dietary Habits','Degree'], dtype=int).drop('Profession',axis=1)
# X_prof_test

# %%
# X_prof=professional_merged.drop('Profession',axis=1)
# y_prof=professional_merged['Profession']

# from sklearn.model_selection import train_test_split
# from sklearn.ensemble import GradientBoostingClassifier,RandomForestClassifier,HistGradientBoostingClassifier
# from sklearn.tree import DecisionTreeClassifier
# from sklearn.metrics import accuracy_score
# gbc=GradientBoostingClassifier()
# gbc.fit(X_prof,y_prof)


# y_pred=gbc.predict(X_prof_test)

# print(y_pred)

# %%
# professional_merged_test['Profession']=y_pred

# %%
# merged_df.loc[(merged_df['Profession'].isnull()) & merged_df['Degree'].isin(['Class 12']), 'Profession'] = y_pred

# %%
# merged_df['Profession'] = merged_df['Profession'].fillna(merged_df['Profession'].mode()[0])
merged_df.isnull().sum()
# Out:
# id                                           0
# Gender                                       0
# Age                                          0
# City                                         0
# Working Professional or Student              0
# Profession                               61262
# Academic Pressure                            0
# Work Pressure                                0
# CGPA                                         0
# Study Satisfaction                           0
# Job Satisfaction                             0
# Sleep Duration                               0
# Dietary Habits                               0
# Degree                                       0
# Have you ever had suicidal thoughts ?        0
# Work/Study Hours                             0
# Financial Stress                             0
# Family History of Mental Illness             0
# Depression                               93800
# dtype: int64

# %%
merged_df.drop('Profession',axis=1,inplace=True)

# %%
merged_df.drop(['Gender','CGPA','Family History of Mental Illness'],axis=1,inplace=True)

# %%
num_df=merged_df.select_dtypes(include=['number'])
num_df.corr()
# Out:
#                                              id       Age  \
# id                                     1.000000 -0.001491
# Age                                   -0.001491  1.000000
# Working Professional or Student        0.001820 -0.584468
# Academic Pressure                      0.003181 -0.069200
# Work Pressure                          0.003551 -0.076542
# Study Satisfaction                     0.000700  0.022228
# Job Satisfaction                      -0.002749  0.018862
# Have you ever had suicidal thoughts ?  0.000826 -0.140980
# Work/Study Hours                      -0.000245 -0.119321
# Financial Stress                      -0.004030 -0.084043
# Depression                             0.003944 -0.564671
#
#                                        Working Professional or Student  \
# id                                                            0.001820
# Age                                                          -0.584468
# ...

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
df_encoded = pd.get_dummies(merged_df, columns=['City','Sleep Duration','Dietary Habits','Degree'], dtype=int)

# %%
df=df_encoded
# df.drop('id',axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234500 entries, 0 to 234499
# Data columns (total 75 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   id                                     234500 non-null  int64
#  1   Age                                    234500 non-null  float64
#  2   Working Professional or Student        234500 non-null  int64
#  3   Academic Pressure                      234500 non-null  float64
#  4   Work Pressure                          234500 non-null  float64
#  5   Study Satisfaction                     234500 non-null  float64
#  6   Job Satisfaction                       234500 non-null  float64
#  7   Have you ever had suicidal thoughts ?  234500 non-null  int64
#  8   Work/Study Hours                       234500 non-null  float64
#  9   Financial Stress                       234500 non-null  float64
# ...

# %%
# df.drop('CGPA',axis=1,inplace=True)
# df

# %%
id=df['id']

# %%
id
# Out:
# 0              0
# 1              1
# 2              2
# 3              3
# 4              4
#            ...
# 234495    234495
# 234496    234496
# 234497    234497
# 234498    234498
# 234499    234499
# Name: id, Length: 234500, dtype: int64

# %%
df.drop('id',axis=1,inplace=True)

# %%
train_df=df[:140700]
test_df=df[140700:]

# %%
X=train_df.drop('Depression',axis=1)
y=train_df['Depression']
X_final_test=test_df.drop('Depression',axis=1)
y_final_test=test_df['Depression']

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier,RandomForestClassifier,HistGradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
# !pip install catboost
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 9.2 MB/s eta 0:00:00
# ...

# %%
from autogluon.tabular import TabularDataset, TabularPredictor
from autogluon.tabular import TabularPredictor

predictor = TabularPredictor(
    label='Depression',  # Target column
    eval_metric='accuracy',
    problem_type='binary'
).fit(
    train_data=train_df,
    presets='best_quality',
    excluded_model_types=['KNN'],
    time_limit=int(3600*3),
    verbosity=2,
)

# Output summary of the training process
results = predictor.fit_summary()
predictor.leaderboard()
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20241130_052023"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.2
# Python Version:     3.10.12
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP PREEMPT_DYNAMIC Thu Jun 27 21:05:47 UTC 2024
# CPU Count:          2
# Memory Avail:       10.39 GB / 12.67 GB (82.0%)
# Disk Space Avail:   79.29 GB / 112.64 GB (70.4%)
# ...
# Presets specified: ['best_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# ...

# %%
y_preds=predictor.predict(test_df)
autogluon=pd.read_csv('/content/sample_submission.csv')
autogluon['Depression']=y_preds.values
autogluon['Depression']=autogluon['Depression'].astype(int)
autogluon.to_csv('autogluon_submission.csv',index=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)

# %%
from sklearn.ensemble import StackingClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, HistGradientBoostingClassifier
from xgboost import XGBClassifier
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis, LinearDiscriminantAnalysis
from sklearn.ensemble import AdaBoostClassifier, BaggingClassifier
from sklearn.metrics import accuracy_score
from sklearn.ensemble import StackingClassifier, ExtraTreesClassifier
from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import xgboost as xgb
import lightgbm as lgb
import catboost as cb
import numpy as np
import pandas as pd
# Out:
# /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)

# %%
# Base models
lgb_model = lgb.LGBMClassifier(random_state=42)
cat_model = cb.CatBoostClassifier(verbose=0, random_state=42)
extratrees_model = ExtraTreesClassifier(random_state=42)
knn_model = KNeighborsClassifier()
svc_model = SVC(probability=True, random_state=42)
nb_model = GaussianNB()
mlp_model = MLPClassifier(random_state=42)
decision_tree_model = DecisionTreeClassifier(random_state=42)
xgb_model = XGBClassifier()
gbc_model = GradientBoostingClassifier()
rfc_model = RandomForestClassifier()
hgbc_model = HistGradientBoostingClassifier()



# Step 3: Create the Stacking Classifier
estimators = [
    ('lgb', lgb_model),
    ('gbc', gbc_model),
    ('rfc', rfc_model),
    ('extratrees', extratrees_model),
    #('knn', knn_model),
    ("adaboost", AdaBoostClassifier(random_state=42)),
    #("lda", LinearDiscriminantAnalysis()),
    ('mlp', mlp_model),
    #('dt', decision_tree_model),
    ('hgbc', hgbc_model),
    ('xgb', xgb_model),
    ('cat', cat_model),
    ('lr', LogisticRegression())
]

stacking_model = StackingClassifier(
    estimators=estimators,
    final_estimator=svc_model,
    cv=5
)

stacking_model.fit(X_train, y_train)

# Predictions
y_pred = stacking_model.predict(X_test)

# Accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Stacking Classifier Accuracy: {accuracy:.4f}")
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 23009, number of negative: 103621
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.020296 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 409
# [LightGBM] [Info] Number of data points in the train set: 126630, number of used features: 76
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.181703 -> initscore=-1.504855
# [LightGBM] [Info] Start training from score -1.504855
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# ...

# %%
from sklearn.ensemble import GradientBoostingClassifier,HistGradientBoostingClassifier
gbc=LogisticRegression(max_iter=1000)
gbc.fit(X_train,y_train)
y_pred=gbc.predict(X_test)
acc_score=accuracy_score(y_test,y_pred)
print(acc_score)
# Out:
# 0.9364605543710022

# %%
from sklearn.ensemble import GradientBoostingClassifier,HistGradientBoostingClassifier

hgbc=HistGradientBoostingClassifier()
hgbc.fit(X_train,y_train)
y_pred=hgbc.predict(X_test)
acc_score=accuracy_score(y_test,y_pred)
print(acc_score)
# Out:
# 0.9357498223169864

# %%
submit = pd.read_csv('/content/sample_submission.csv')
submit['Depression'] = y_pred
submit.to_csv('submission.csv', index=False)

# %%
from sklearn.ensemble import RandomForestClassifier

rfc=RandomForestClassifier()
rfc.fit(X_train,y_train)
y_pred=rfc.predict(X_test)
acc_score=accuracy_score(y_test,y_pred)
print(acc_score)
# Out:
# 0.935820895522388

# %%
from xgboost import XGBClassifier


bst = XGBClassifier()

bst.fit(X_train, y_train)

preds = bst.predict(X_test)

acc_score=accuracy_score(y_test,preds)
print(acc_score)
# Out:
# 0.9378109452736318

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report

# Define the parameter grid
param_grid = {
    'learning_rate': [0.1, 0.01, 0.001, 0.005],          # Regularization parameter
    'max_iter': [100, 200, 500], # Kernel coefficient
    'max_leaf_nodes': [25,30,35,40],
    'l2_regularization':[0.001,0.01,0.005]# Kernel type
}

# Create a GridSearchCV object
grid_search = GridSearchCV(estimator=hgbc, param_grid=param_grid, cv=2, scoring='accuracy', verbose=2, n_jobs=-1)

# Fit the grid search to the data
grid_search.fit(X, y)

# Print the best parameters and best score
print("Best Parameters:", grid_search.best_params_)
print("Best Cross-Validation Accuracy:", grid_search.best_score_)

# Evaluate the model with the best parameters on the test set
best_model = grid_search.best_estimator_
print(best_model)
y_pred = best_model.predict(X_final_test)

# Print the classification report
# print("Classification Report on Test Set:\n")
# print(classification_report(y_test, y_pred))
# print(accuracy_score(y_test,y_pred))
# Out:
# Fitting 2 folds for each of 144 candidates, totalling 288 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-259-f778c01b3f2c> in <cell line: 16>()
#      14
#      15 # Fit the grid search to the data
# ---> 16 grid_search.fit(X, y)
#      17
#      18 # Print the best parameters and best score
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#    1474
#    1475         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, **params)
#    1017                 return results
#    1018
# -> 1019             self._run_search(evaluate_candidates)
#    1020
# ...

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report

# Define the parameter grid
param_grid = {
    'n_estimators': [100,500,1000],
    'criterion':['gini', 'entropy', 'log_loss'],
    'max_depth': [None, 10, 20, 30],
    #'min_samples_split': [2, 5, 10],
    #'min_samples_leaf': [1, 2, 4],
    'max_features': [None, 'sqrt', 'log2']
}

# Create a GridSearchCV object
grid_search = GridSearchCV(estimator=rfc, param_grid=param_grid, cv=2, scoring='accuracy', verbose=2, n_jobs=-1)

# Fit the grid search to the data
grid_search.fit(X_train, y_train)

# Print the best parameters and best score
print("Best Parameters:", grid_search.best_params_)
print("Best Cross-Validation Accuracy:", grid_search.best_score_)

# Evaluate the model with the best parameters on the test set
best_model = grid_search.best_estimator_
print(best_model)
y_pred = best_model.predict(X_test)

# Print the classification report
print("Classification Report on Test Set:\n")
print(classification_report(y_test, y_pred))
print(accuracy_score(y_test,y_pred))
# Out:
# Fitting 2 folds for each of 108 candidates, totalling 216 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-56-48c19e32f7f5> in <cell line: 18>()
#      16
#      17 # Fit the grid search to the data
# ---> 18 grid_search.fit(X_train, y_train)
#      19
#      20 # Print the best parameters and best score
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#    1474
#    1475         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, **params)
#    1017                 return results
#    1018
# -> 1019             self._run_search(evaluate_candidates)
#    1020
# ...

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report

# Define the parameter grid
param_grid = {
    'loss':['log_loss', 'exponential'],
    'learning_rate': [0.1, 0.01, 0.001],
    'n_estimators': [100, 200, 500],
    'subsample': [0.1,0.01,0.001],
    'criterion':['friedman_mse', 'squared_error']
}

# Create a GridSearchCV object
grid_search = GridSearchCV(estimator=gbc, param_grid=param_grid, cv=3, scoring='accuracy', verbose=2, n_jobs=-1)

# Fit the grid search to the data
grid_search.fit(X, y)

# Print the best parameters and best score
print("Best Parameters:", grid_search.best_params_)
print("Best Cross-Validation Accuracy:", grid_search.best_score_)

# Evaluate the model with the best parameters on the test set
best_model = grid_search.best_estimator_
print(best_model)
y_pred = best_model.predict(X_final_test)

# Print the classification report
# print("Classification Report on Test Set:\n")
# print(classification_report(y_test, y_pred))
# print(accuracy_score(y_test,y_pred))
# Out:
# Fitting 3 folds for each of 108 candidates, totalling 324 fits
# Best Parameters: {'criterion': 'squared_error', 'learning_rate': 0.01, 'loss': 'exponential', 'n_estimators': 500, 'subsample': 0.1}
# Best Cross-Validation Accuracy: 0.9324022743425728
# GradientBoostingClassifier(criterion='squared_error', learning_rate=0.01,
#                            loss='exponential', n_estimators=500, subsample=0.1)

# %%
# from sklearn.ensemble import GradientBoostingClassifier,HistGradientBoostingClassifier
# gbc=RandomForestClassifier()
#hgbc=HistGradientBoostingClassifier(l2_regularization=0.006)
bst.fit(X,y)
y_pred=bst.predict(X_final_test)
print(y_pred)
# Out:
# [0 0 0 ... 0 1 0]

# %%
test_df['Depression']=y_pred
# Out:
# <ipython-input-298-e1fd54bd71b3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['Depression']=y_pred

# %%
test_df
# Out:
#         Gender   Age  Working Professional or Student  Academic Pressure  \
# 140700       0  53.0                                0                3.0
# 140701       1  58.0                                0                3.0
# 140702       0  53.0                                0                3.0
# 140703       1  23.0                                1                5.0
# 140704       0  47.0                                0                3.0
# ...        ...   ...                              ...                ...
# 234495       1  49.0                                0                3.0
# 234496       0  29.0                                0                3.0
# 234497       0  24.0                                1                1.0
# 234498       1  23.0                                0                3.0
# 234499       1  43.0                                0                3.0
#
#         Work Pressure  Study Satisfaction  Job Satisfaction  \
# ...

# %%
test_df['id']=id[140700:]
test_df['id']
# Out:
# <ipython-input-305-12ef80e05410>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['id']=id[140700:]
# 140700    140700
# 140701    140701
# 140702    140702
# 140703    140703
# 140704    140704
#            ...
# 234495    234495
# 234496    234496
# 234497    234497
# 234498    234498
# 234499    234499
# Name: id, Length: 93800, dtype: int64

# %%
final_df=test_df[['id','Depression']]
final_df['Depression'].value_counts()
# Out:
# Depression
# 0    77170
# 1    16630
# Name: count, dtype: int64

# %%
final_df['Depression'].astype(int)
# Out:
# 140700    0
# 140701    0
# 140702    0
# 140703    1
# 140704    0
#          ..
# 234495    0
# 234496    1
# 234497    0
# 234498    1
# 234499    0
# Name: Depression, Length: 93800, dtype: int64

# %%
final_df
# Out:
#             id  Depression
# 140700  140700           0
# 140701  140701           0
# 140702  140702           0
# 140703  140703           1
# 140704  140704           0
# ...        ...         ...
# 234495  234495           0
# 234496  234496           1
# 234497  234497           0
# 234498  234498           1
# 234499  234499           0
#
# [93800 rows x 2 columns]

# %%
final_df.to_csv('submission.csv',index=False)
